# %%
import pandas as pd

#Load the dataset
df = pd.read_csv(r'D:\CloudCredits Projects\fraudlens\data\Base.csv')

print(f"Dataset loaded! Shape: {df.shape}")
# Out:
# Dataset loaded! Shape: (1000000, 32)

# %%
df.head()
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0                0     0.3               0.986506                         -1
# 1                0     0.8               0.617426                         -1
# 2                0     0.8               0.996707                          9
# 3                0     0.6               0.475100                         11
# 4                0     0.9               0.842307                         -1
# ...            ...     ...                    ...                        ...
# 999995           0     0.8               0.124690                         -1
# 999996           0     0.9               0.824544                         -1
# 999997           0     0.8               0.140891                         -1
# 999998           0     0.9               0.002480                         52
# 999999           0     0.6               0.993391                         -1
#
# ...

# %%
df.describe()
# Out:
#            fraud_bool          income  name_email_similarity  \
# count  1000000.000000  1000000.000000         1000000.000000
# mean         0.011029        0.562696               0.493694
# std          0.104438        0.290343               0.289125
# min          0.000000        0.100000               0.000001
# 25%          0.000000        0.300000               0.225216
# 50%          0.000000        0.600000               0.492153
# 75%          0.000000        0.800000               0.755567
# max          1.000000        0.900000               0.999999
#
#        prev_address_months_count  current_address_months_count  \
# count             1000000.000000                1000000.000000
# mean                   16.718568                     86.587867
# std                    44.046230                     88.406599
# min                    -1.000000                     -1.000000
# 25%                    -1.000000                     19.000000
# ...

# %%
df.isnull().sum()
# Out:
# fraud_bool                          0
# income                              0
# name_email_similarity               0
# prev_address_months_count           0
# current_address_months_count        0
# customer_age                        0
# days_since_request                  0
# intended_balcon_amount              0
# payment_type                        0
# zip_count_4w                        0
# velocity_6h                         0
# velocity_24h                        0
# velocity_4w                         0
# bank_branch_count_8w                0
# date_of_birth_distinct_emails_4w    0
# employment_status                   0
# credit_risk_score                   0
# email_is_free                       0
# housing_status                      0
# phone_home_valid                    0
# phone_mobile_valid                  0
# bank_months_count                   0
# has_other_cards                     0
# proposed_credit_limit               0
# foreign_request                     0
# ...

# %%
# Calculate absolute counts and percentages for the fraud_bool column
fraud_counts = df['fraud_bool'].value_counts()
fraud_percentages = df['fraud_bool'].value_counts(normalize=True) * 100

print("--- Fraud Class Balance ---")
print(f"Legitimate (0): {fraud_counts[0]:,} rows ({fraud_percentages[0]:.2f}%)")
print(f"Fraudulent (1): {fraud_counts[1]:,} rows ({fraud_percentages[1]:.2f}%)")
print(f"Total Dataset Size: {len(df):,} rows")
# Out:
# --- Fraud Class Balance ---
# Legitimate (0): 988,971 rows (98.90%)
# Fraudulent (1): 11,029 rows (1.10%)
# Total Dataset Size: 1,000,000 rows
